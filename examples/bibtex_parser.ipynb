# %%
import bibtexparser
import pandas as pd

# %%
with open("bioarxiv_aif_citations.bib") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
    
df = pd.DataFrame(bib_database.entries)
# selection = df[['doi', 'number']]

# %%
df[["title", "author", "year"]]
# Out:
#                                                  title  \
# 0    A systematic analysis of the effects of splici...
# 1    Feature selectivity of corticocortical feedbac...
# 2    Generalized cue reactivity in dopamine neurons...
# 3    Physiological Harmony or Discord? Unveiling th...
# 4               Embodied decisions as active inference
# ..                                                 ...
# 522  Human inferences about sequences: A minimal tr...
# 523                An Atlas of Human Kinase Regulation
# 524                              Habits without Values
# 525  The role of brain oscillations in predicting t...
# 526  Recovery of dynamics and function in spiking n...
#
#                                                 author  year
# 0    Crowl, Sam and Coleman, Maeve Bella and Chaphi...  2024
# 1    Korkian, Yavar and Nakhla, Nardin and Pack, Ch...  2024
# 2    Lehmann, Collin M. and Miller, Nora E. and Nai...  2024
# ...
