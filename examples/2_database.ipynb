# %% [markdown]
# ## Example 1: Using the `Database` class
#
# This notebook demonstrates how to use the `Database` class to load/save existing database or create new database.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("..")

from src.db import Database

TABLE_DIR = "data/tables/2023_09_14"
TAG_PATH = "data/tags/tags.yaml"

# %% [markdown]
# ## Create a database, attach tags, and save the database

# %%
database = Database()
database.create(table_dir=TABLE_DIR)
database.attach_tags(tag_path=TAG_PATH)
database.save()
# Out:
# INFO:src.db:Loading tables...
# INFO:src.db:Database created at 2025-03-21 17:12:35.196730.
# INFO:src.db:Loading tags...
# INFO:src.tags:YAML tag file successfully loaded from data/tags/tags.yaml.
# INFO:src.db:Adding tags to database...
# INFO:src.db:Database saved to data/databases/database__2025-03-21__17:12:35.196730.pkl.

# %% [markdown]
# ## Load a database

# %%
database = Database()
database.load("data/databases/database__2025-03-21__17:12:35.196730.pkl")
database.db
# Out:
# INFO:src.db:Database loeaded from data/databases/database__2025-03-21__17:12:35.196730.pkl.
#                                                   title  \
# 0     Friston's free energy principle: new life for ...
# 1                        Friston's theory of everything
# 2                  Voxel-based morphometry--the methods
# 3     Scientific realism about Friston blankets with...
# 4     Structural and functional brain networks: from...
# ...                                                 ...
# 3580  Changes in both top-down and bottom-up effecti...
# 3581  Spectral-temporal EEG dynamics of speech discr...
# 3582  A robot or a dumper truck? Facilitating play-b...
# 3583  The neurophenomenology of early psychosis: An ...
# 3584  Noradrenergic deficits contribute to apathy in...
#
#                                                 authors  \
# 0                                             Holmes J.
# 1                                            McCrone J.
# 2                              Ashburner J, Friston KJ.
# 3                            Kiverstein J, Kirchhoff M.
# 4                                   Park HJ, Friston K.
# ...                                                 ...
# 3580  Thomas GEC, Zeidman P, Sultana T, Zarkali A, R...
# 3581   Gilley PM, Uhler K, Watson K, Yoshinaga-Itano C.
# 3582  Paldam E, Roepstorff A, Steensgaard R, Lundsga...
# 3583  Nelson B, Lavoie S, Gawęda Ł, Li E, Sass LA, K...
# 3584  Hezemans FH, Wolpe N, O'Callaghan C, Ye R, Rua...
#
#              where_published  year                            doi  \
# 0               BJPsych Bull  2022             10.1192/bjb.2021.6
# 1              Lancet Neurol  2022  10.1016/S1474-4422(22)00137-5
# 2                 Neuroimage  2000         10.1006/nimg.2000.0582
# 3            Behav Brain Sci  2022      10.1017/S0140525X22000267
# 4                    Science  2013        10.1126/science.1238411
# ...                      ...   ...                            ...
# 3580            Brain Commun  2022     10.1093/braincomms/fcac329
# 3581            BMC Neurosci  2017      10.1186/s12868-017-0353-4
# 3582  Autism Dev Lang Impair  2022      10.1177/23969415221086714
# 3583          Conscious Cogn  2020   10.1016/j.concog.2019.102845
# 3584        PLoS Comput Biol  2022   10.1371/journal.pcbi.1010079
#
#                                                     tag
# 0                       [psychoanalysis, psychotherapy]
# 1                                           [editorial]
# 2                                [review, neuroimaging]
# 3     [Markov blankets, philosophy, comment / response]
# 4                            [review, network analysis]
# ...                                                 ...
# 3580                            [predictive processing]
# 3581                            [predictive processing]
# 3582                            [predictive processing]
# 3583                            [predictive processing]
# 3584                            [predictive processing]
#
# [3585 rows x 6 columns]

# %% [markdown]
# ## Detaching a database

# %%
database.detach()
# Out:
# INFO:src.db:Database detached.

# %% [markdown]
# ## Remove papers from database

# %%
papers_to_remove = ["10.1192/bjb.2021.6", "10.1016/S1474-4422(22)00137-5"]
database.remove(doi_list=papers_to_remove)

database.db
# Out:
#                                                   title  \
# 0                  Voxel-based morphometry--the methods
# 1     Scientific realism about Friston blankets with...
# 2     Structural and functional brain networks: from...
# 3       Functional and effective connectivity: a review
# 4                               Bayesian Dysconnections
# ...                                                 ...
# 3578  Changes in both top-down and bottom-up effecti...
# 3579  Spectral-temporal EEG dynamics of speech discr...
# 3580  A robot or a dumper truck? Facilitating play-b...
# 3581  The neurophenomenology of early psychosis: An ...
# 3582  Noradrenergic deficits contribute to apathy in...
#
#                                                 authors  \
# 0                              Ashburner J, Friston KJ.
# 1                            Kiverstein J, Kirchhoff M.
# 2                                   Park HJ, Friston K.
# 3                                           Friston KJ.
# 4                                           Friston KJ.
# ...                                                 ...
# 3578  Thomas GEC, Zeidman P, Sultana T, Zarkali A, R...
# 3579   Gilley PM, Uhler K, Watson K, Yoshinaga-Itano C.
# 3580  Paldam E, Roepstorff A, Steensgaard R, Lundsga...
# 3581  Nelson B, Lavoie S, Gawęda Ł, Li E, Sass LA, K...
# 3582  Hezemans FH, Wolpe N, O'Callaghan C, Ye R, Rua...
#
#              where_published  year                             doi  \
# 0                 Neuroimage  2000          10.1006/nimg.2000.0582
# 1            Behav Brain Sci  2022       10.1017/S0140525X22000267
# 2                    Science  2013         10.1126/science.1238411
# 3              Brain Connect  2011         10.1089/brain.2011.0008
# 4            Am J Psychiatry  2020  10.1176/appi.ajp.2020.20091421
# ...                      ...   ...                             ...
# 3578            Brain Commun  2022      10.1093/braincomms/fcac329
# 3579            BMC Neurosci  2017       10.1186/s12868-017-0353-4
# 3580  Autism Dev Lang Impair  2022       10.1177/23969415221086714
# 3581          Conscious Cogn  2020    10.1016/j.concog.2019.102845
# 3582        PLoS Comput Biol  2022    10.1371/journal.pcbi.1010079
#
#                                                     tag
# 0                                [review, neuroimaging]
# 1     [Markov blankets, philosophy, comment / response]
# 2                            [review, network analysis]
# 3     [review, neuroanatomy, neuroimaging, network a...
# 4           [editorial, schizophrenia, psychopathology]
# ...                                                 ...
# 3578                            [predictive processing]
# 3579                            [predictive processing]
# 3580                            [predictive processing]
# 3581                            [predictive processing]
# 3582                            [predictive processing]
#
# [3583 rows x 6 columns]

# %% [markdown]
# ## Update database from dict

# %%
papers = [{
    "doi"    : "https://doi.org/10.48550/arXiv.2409.15532",
    "authors": [
        "Lancelot Da Costa", "Nathael Da Costa", "Conor Heins", "Johan Medrano", "Grigorios A. Pavliotis", "Thomas Parr", "Ajith Anil Meera", "Karl Friston"],
    "where_published": "ArXiv",
    "year": 2024,
    "title": "A theory of generalised coordinates for stochastic differential equations"
},
{
    "doi" : "https://doi.org/10.48550/arXiv.2503.13223",
    "authors" : ["Allahkaram Shafiei", "Hozefa Jesawada", "Karl Friston", "Giovanni Russo"],
    "where_published": "ArXiv",
    "year": 2025,
    "title": "Robust Decision-Making Via Free Energy Minimization"
}]

# %%
database.update_from_dicts_list(entries=papers)
database.db

# %%
database.update_from_CSV(csv_path="/home/sanjeev/Documents/git_repos/aif-fep-db/examples/test_entry.csv")
database.db
# Out:
#                                                   title  \
# 0     Friston's free energy principle: new life for ...
# 1                        Friston's theory of everything
# 2                  Voxel-based morphometry--the methods
# 3     Scientific realism about Friston blankets with...
# 4     Structural and functional brain networks: from...
# ...                                                 ...
# 3582  A robot or a dumper truck? Facilitating play-b...
# 3583  The neurophenomenology of early psychosis: An ...
# 3584  Noradrenergic deficits contribute to apathy in...
# 3585  A theory of generalised coordinates for stocha...
# 3586  Robust Decision-Making Via Free Energy Minimiz...
#
#                                                 authors  \
# 0                                             Holmes J.
# 1                                            McCrone J.
# 2                              Ashburner J, Friston KJ.
# 3                            Kiverstein J, Kirchhoff M.
# 4                                   Park HJ, Friston K.
# ...                                                 ...
# 3582  Paldam E, Roepstorff A, Steensgaard R, Lundsga...
# 3583  Nelson B, Lavoie S, Gawęda Ł, Li E, Sass LA, K...
# 3584  Hezemans FH, Wolpe N, O'Callaghan C, Ye R, Rua...
# 3585  [Lancelot Da Costa, Nathael Da Costa, Conor He...
# 3586  [Allahkaram Shafiei, Hozefa Jesawada, Karl Fri...
#
#              where_published  year                            doi  \
# 0               BJPsych Bull  2022             10.1192/bjb.2021.6
# 1              Lancet Neurol  2022  10.1016/S1474-4422(22)00137-5
# 2                 Neuroimage  2000         10.1006/nimg.2000.0582
# 3            Behav Brain Sci  2022      10.1017/S0140525X22000267
# 4                    Science  2013        10.1126/science.1238411
# ...                      ...   ...                            ...
# 3582  Autism Dev Lang Impair  2022      10.1177/23969415221086714
# 3583          Conscious Cogn  2020   10.1016/j.concog.2019.102845
# 3584        PLoS Comput Biol  2022   10.1371/journal.pcbi.1010079
# 3585                   ArXiv  2024      10.48550/arXiv.2409.15532
# 3586                   ArXiv  2025      10.48550/arXiv.2503.13223
#
#                                                     tag
# 0                       [psychoanalysis, psychotherapy]
# 1                                           [editorial]
# 2                                [review, neuroimaging]
# 3     [Markov blankets, philosophy, comment / response]
# 4                            [review, network analysis]
# ...                                                 ...
# 3582                            [predictive processing]
# 3583                            [predictive processing]
# 3584                            [predictive processing]
# 3585                                         [untagged]
# 3586                                         [untagged]
#
# [3587 rows x 6 columns]

# %%
import pandas as pd
from ast import literal_eval

csv_path = "/home/sanjeev/Documents/git_repos/aif-fep-db/examples/test_entry.csv"
papers = pd.read_csv(csv_path, converters={"authors": literal_eval, "tag": literal_eval})
papers = papers.to_dict(orient="records")

# %%
database.db.iloc[-2:, :].to_csv("test_entry.csv", index=False)

# %%
import re

DOI_REGEX_PATTERN = r"^10\.\d{4,9}/[-._;()/:A-Z0-9]+$"
doi = "https://doi.org/10.48550/arXiv.2409.15532"
doi = doi.strip("https://doi.org/")

match = re.match(DOI_REGEX_PATTERN, doi, re.IGNORECASE)

if not bool(match):
    print(f"Warning: {doi} failed DOI validation!")

# %%
from src.utils import load_tables

table_dir = "data/tables/2024_07_22"
table_names = os.listdir(table_dir)
table_paths = [table_dir + "/" + table_name for table_name in table_names]
table_list = load_tables(table_dir)


for idx, table in enumerate(table_list):
    table.drop(["PMID", "Citation", "First Author", "Create Date", "PMCID", "NIHMS ID"], axis=1, inplace=True)
    table.columns = ["title", "authors", "where_published", "year", "doi"]
    table.to_csv(table_paths[idx])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_164829/2451361166.py in <module>
#       8
#       9 for idx, table in enumerate(table_list):
# ---> 10     table.drop(["PMID", "Citation", "First Author", "Create Date", "PMCID", "NIHMS ID"], axis=1, inplace=True)
#      11     table.columns = ["title", "authors", "where_published", "year", "doi"]
#      12     table.to_csv(table_paths[idx])
#
# ~/anaconda3/envs/ds_env_1/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/ds_env_1/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4946                 weight  1.0     0.8
#    4947         """
# -> 4948         return super().drop(
#    4949             labels=labels,
#    4950             axis=axis,
#
# ~/anaconda3/envs/ds_env_1/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277         for axis, labels in axes.items():
#    4278             if labels is not None:
# -> 4279                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4280
#    4281         if inplace:
#
# ~/anaconda3/envs/ds_env_1/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4322             else:
# -> 4323                 new_axis = axis.drop(labels, errors=errors)
#    4324             indexer = axis.get_indexer(new_axis)
#    4325
#
# ~/anaconda3/envs/ds_env_1/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6642         if mask.any():
#    6643             if errors != "ignore":
# -> 6644                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645             indexer = indexer[~mask]
#    6646         return self.delete(indexer)
#
# KeyError: "['PMID', 'Citation', 'First Author', 'Create Date', 'PMCID', 'NIHMS ID'] not found in axis"

# %%
import pandas as pd

db_list = []
table_dir = "data/tables/2023_09_14"
table_names = os.listdir(table_dir)
table_paths = [table_dir + "/" + table_name for table_name in table_names]

for table_path in table_paths:
    table = pd.read_csv(table_path)
    db_list.append(table)
# Out:
# datetime.datetime
