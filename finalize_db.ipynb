# %% [markdown]
# # Notebook to compile ArXiv, PsyArXiv, and BioArXiv papers into a single database

# %%
from src.db import Database

# %%
# Import Pubmed
database = Database()
database.create("data/tables/2024_07_22")
pubmed = database.db

# Import ArXiv and PsyArXiv

# Import BioArXiv

# Compile
# Out:
# INFO:src.db:Loading tables...
# INFO:src.db:Database created at 2025-04-10 10:51:47.268236.
#                                                  title  \
# 0    Reliability of dynamic causal modelling of res...
# 1    Global neural self-disturbance in schizophreni...
# 2    'Snakes and ladders' in paleoanthropology: Fro...
# 3    Two distinct networks for encoding goals and f...
# 4    The Universal Optimism of the Self-Evidencing ...
# ..                                                 ...
# 758  Extrapolative delay compensation through facil...
# 759  New architecture for MPEG video streaming syst...
# 760  A basis for generating expectancies for verbs ...
# 761  Mental state inference using visual control pa...
# 762  Integration of syntactic and semantic informat...
#
#                                                authors  \
# 0    Jafarian A, Assem MK, Kocagoncu E, Lanskey JH,...
# 1                               Sabbah SG, Northoff G.
# 2                  Manrique HM, Friston KJ, Walker MJ.
# 3    Di Cesare G, Lombardi G, Zeidman P, Urgen BA, ...
# 4                                  Fisher EL, Hohwy J.
# ..                                                 ...
# 758                                     Lim H, Choe Y.
# 759                     Fu CH, Chan YL, Ip TP, Siu WC.
# 760             McRae K, Hare M, Elman JL, Ferretti T.
# 761                      Oztop E, Wolpert D, Kawato M.
# 762                 Kamide Y, Scheepers C, Altmann GT.
#
#               where_published  year                                doi
# 0              Hum Brain Mapp  2024                  10.1002/hbm.26782
# 1               Schizophr Res  2024       10.1016/j.schres.2024.05.015
# 2               Phys Life Rev  2024        10.1016/j.plrev.2024.01.004
# 3    Proc Natl Acad Sci U S A  2024            10.1073/pnas.2402282121
# 4             Entropy (Basel)  2024                  10.3390/e26060518
# ..                        ...   ...                                ...
# 758    IEEE Trans Neural Netw  2008           10.1109/TNN.2008.2001002
# 759  IEEE Trans Image Process  2007            10.1109/tip.2007.902330
# 760                Mem Cognit  2005                 10.3758/bf03193221
# 761  Brain Res Cogn Brain Res  2005  10.1016/j.cogbrainres.2004.08.004
# 762      J Psycholinguist Res  2003            10.1023/a:1021933015362
#
# [3981 rows x 5 columns]
